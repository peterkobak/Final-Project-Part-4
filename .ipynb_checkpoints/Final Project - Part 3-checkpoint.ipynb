# %% [markdown]
# ### Goal: Merge the data sets below into one clean data set that can be used to perform basic exploratory data analysis.
#
# ## Data Sets Used
#
# **Fire Inspections (2017)**
# Catalogues inspection results for non-residential buildings Why: How long ago an inspection occured may impact the risk of a fire in the near future.
# Peoria Fire Department
#
# **OVAP Scores (2017)**
# OVAP scores inform the Fire Department to what extent a building might be likely to have a fire incident. The OVAP scores have only been generated since new software was implemented in 2017.
# Peoria Fire Department
#
# **Building Characteristics**
# Catalogues several characteristics of all buildings, such as year built, square footage, etc. Why: Some building characteristics may impact the risk of a fire in the future. For example, older buildings may contain knob-and-tube electrical wiring, which is less safe than modern electrical wiring.
# Peoria County GIS Department / City of Peoria Information Systems Department
#
# _Optional_
#
# **Code Violations**
# (Dates?)
# Catalogues ordinance violations found when inspecting buildings Why: Code violations may point to issues that could cause a fire, such as exposed electrical wiring.
# City of Peoria Community Development Department
#
# ### __Names of the datasets that we're working with:__
#
# 1. commercial_building_list.csv - commercial buildings in the city with firezone id and firestation (Building Characteristics)
# 2. inspection_data_2017.csv - fire inspections in 2017, pulled from current Peoria Fire Department tool (Fire Inspections)
# 3. commercial_with_OVAP_score.csv - commercial buildings that have OVAP scores, pulled from current Peoria Fire Department Tool (OVAPs)

# %% [markdown]
# ## Step 1
#
# Merge the 3 data sets so that we have one final data set of all commercial buildings with inspection results and OVAP scores for 2017.

# %%
## 1. Import all 3 data sets to take a look at their columns

import pandas as pd
from pathlib import Path

## 1.a Set path for data sets

inspections_path = Path('.', 'data', 'inspection_data_2017.csv')
buildings_path = Path('.', 'data', 'commercial_building_list.csv')
OVAP_path = Path('.', 'data', 'commercial_with_OVAP_score.csv')

## 1.b Read in data to variables

inspections = pd.read_csv(inspections_path)
buildings = pd.read_csv(buildings_path)
OVAP = pd.read_csv(OVAP_path)

## 1.c Take a look at how the 3 dataframes display address information, which
## will be the column on which we will eventually join them.

print(buildings.loc[:,'full_address'].head())
print(inspections.loc[:, 'Address1'].head())
print(OVAP.loc[:, 'Address'].head())

OVAP.head()
# Out:
# 0        10405 N JULIET CT
# 1    10225 N KNOXVILLE AVE
# 2           1715 W ALTA RD
# 3           1601 W ALTA RD
# 4           1415 W ALTA RD
# Name: full_address, dtype: object
# 0    4700 N University ST #60
# 1             100 State ST #A
# 2              1024 W MAIN ST
# 3        2607 N University ST
# 4           100 Alexander AVE
# Name: Address1, dtype: object
# 0      8875 N Knoxville AVE
# 1          Peoria, IL 61615
# 2    2200 W War Memorial DR
# 3                    #DU19A
# 4          Peoria, IL 61613
# Name: Address, dtype: object
#                Occupancy Name                 Address  NFF GPM Flow Available  \
# 0  Academy of Okinawan Karate    8875 N Knoxville AVE      0.0   Insufficient
# 1                         NaN        Peoria, IL 61615      NaN            NaN
# 2   the former Napoli's Pizza  2200 W War Memorial DR    196.0     Sufficient
# 3                         NaN                  #DU19A      NaN            NaN
# 4                         NaN        Peoria, IL 61613      NaN            NaN
#
#    OVAP Score
# 0        0.00
# 1         NaN
# 2       29.46
# 3         NaN
# 4         NaN

# %%
## 2. Clean the dataframes - Removing Columns

## 2.a Remove unnecessary columns in buildings dataframe

buildings.drop(['street_number', 'street_directionality', 'street_name', 'street_type', 'owner_middleinitial'], axis=1, inplace=True)
buildings.columns
# Out:
# Index(['feature_ID', 'lower_PIN', 'PIN', 'owner_name', 'owner_address',
#        'owner_address2', 'owner_city', 'owner_state', 'full_address', 'city',
#        'state', 'zipcode', 'tax_code', 'first_name', 'last_name',
#        'firestation', 'firezone'],
#       dtype='object')

# %%
## 2.b Remove unnecessary columns in OVAP dataframe

OVAP.drop(['NFF GPM', 'Flow Available'], axis=1, inplace=True)
OVAP.columns
# Out:
# Index(['Occupancy Name', 'Address', 'OVAP Score'], dtype='object')

# %%
## 2.c Remove unnecessary columns in inspections dataframe - based on Roland's recommendations

inspections.drop(['Subcategory',
       'Email', 'Phone', 'FAX', 'OccupancyNotes', 'MapPage',
       'FireAlarmPanelLoc', 'MasterKeyLoc',
       'BasementPresent', 'Width', 'Length', 'GasLPGShutoffLoc',
       'ElectricalPanelLoc', 'FDConnections', 'SprinklerRoomLoc',
       'OtherLocInfo', 'WaterSupplyInfo', 'ExposureInfo', 'HazMat',
       'BuildingAccess', 'AccessProblems', 'VentilationProblems',
       'TimeNormallyOccupied', 'PrePlanNotes', 'UserOccupancyID',
       'LicenseNumber', 'NumberOfUnits', 'OccupancyLoad', 'UBCode', 'NFPACode',
       'IBCode', 'AssessorParcelNumber', 'NumberMilepost',
       'StreetPrefixDirection', 'StreetOrHighwayName', 'StreetType',
       'StreetSuffix', 'AptOrSuite', 'ISOID', 'Latitude',
       'BuildingNumber', 'Longitude',
       'AssessedValue', 'NationalGrid',
       'UtilityBillingNumber', 'RoofTypeId', 'RoofMaterialId',
       'RoofConstructionId', 'StationID', 'DispatchID',
       'Population DensityID'], axis=1, inplace=True)
inspections.columns
# Out:
# Index(['Name', 'Address1', 'Address2', 'City', 'State', 'Zip', 'OccupancyType',
#        'BuildingHeight', 'NumberOfFloors', 'SquareFeet',
#        'CriticalInfrastructure', 'YearBuilt', 'NFIRSPropertyUse',
#        'ConstructionTypeId'],
#       dtype='object')

# %%
## 3. Clean the dataframes - Adding columns

## 3.a view the OVAP score data set

OVAP.head()

## For every inspection in The OVAP Score data set, there is row for the address,
## another rows with City, State, ZIP and, if relevant, a third row with Unit information. 
## To clean up the OVAP dataframe, we need to remove City, State, and ZIP. 
## Then, we need to add a column to the row with the inspection and address that will denote the building's unit,
## if it exists.
# Out:
#                Occupancy Name                 Address  OVAP Score
# 0  Academy of Okinawan Karate    8875 N Knoxville AVE        0.00
# 1                         NaN        Peoria, IL 61615         NaN
# 2   the former Napoli's Pizza  2200 W War Memorial DR       29.46
# 3                         NaN                  #DU19A         NaN
# 4                         NaN        Peoria, IL 61613         NaN

# %%
## 3.b Add a "Unit" column to the OVAP data set and fill it with placeholder values 'NaN'.

OVAP.insert(2, 'Unit', 'NaN')
OVAP.head()
# Out:
#                Occupancy Name                 Address Unit  OVAP Score
# 0  Academy of Okinawan Karate    8875 N Knoxville AVE  NaN        0.00
# 1                         NaN        Peoria, IL 61615  NaN         NaN
# 2   the former Napoli's Pizza  2200 W War Memorial DR  NaN       29.46
# 3                         NaN                  #DU19A  NaN         NaN
# 4                         NaN        Peoria, IL 61613  NaN         NaN

# %%
## 4. Clean the dataframes - Consolidate Unit number into proper address row.

## 4.a Write a for loop to move unit information from 'Address' column to previous row's 'Unit' column.

## Find number of rows in OVAP by saving the rows from .shape to a variable OVAP_row_length
OVAP_row_length = OVAP.shape[0]

## Create a copy of the OVAP to work with moving forward
OVAP_test = OVAP

## Go through all rows in OVAP_test
for row in range(0, OVAP_row_length):
    
    ## If row's Occupancy Name is a str, this means it is a row with an inspection - skip this row
    if type(OVAP_test.loc[row, 'Occupancy Name']) == str:
        pass
    
    ## Else, the row is not an inspection row, but a row that contains either 1) city, state and zip
    ## ir 2) unit information. Check to see if '#' is in the Address column of this row - if true, 
    ## this must be a row with a Unit number.
    else:
        if '#' in OVAP_test.loc[row, 'Address']:
            
            ## If true, this is a Unit number and is moved to the previous row's Unit column.
            ## Then, drop this column.
            OVAP_test.loc[row-1, 'Unit'] = OVAP_test.loc[row, 'Address']
            OVAP_test.drop(row, inplace=True)
            
        ## Else, this is City, State, and ZIP and is not needed, so it is dropped.    
        else:
            OVAP_test.drop(row, inplace=True)
            
## See the resulting dataframe        
OVAP_test.head(20)
# Out:
#                            Occupancy Name                     Address    Unit  \
# 0              Academy of Okinawan Karate        8875 N Knoxville AVE     NaN
# 2               the former Napoli's Pizza      2200 W War Memorial DR  #DU19A
# 5                 (Office w/ Unkown name)                 701 Main ST      #7
# 8                     (vacant mercantile)      2200 W War Memorial DR   #DU08
# 11          1505 on the Avenue Apartments           1505 N Peoria AVE     NaN
# 13                           311 SW Water             311 SW Water ST     NaN
# 15                  401 Management Office             401 SW Water ST    #201
# 18                   401 Water - CAFE 401             401 SW Water ST    #102
# 22  401 Water - Hodges Loizzi Eisenhammer             401 SW Water ST    #106
# 25                       401 Water - VOLT             401 SW Water ST    #101
# 28                               5 Senses  5037 W American Prairie DR     NaN
# 30                         8 Bit Beercade                100 State ST      #A
# 33                       A WORLD OF WINGS              1024 W MAIN ST     NaN
# 35             AAIM Employers Association             401 SW Water ST     NaN
# 37                    AAMCO Transmissions        512 NE Jefferson AVE     NaN
# 39               Aaron Simmons State Farm               318 W McClure     NaN
# 41                       Abes Carmel corn        4700 N University ST     #11
# 45                      Academy of Awards                 701 Main ST      #3
# 48                    Accel Entertainment         921 W Detweiller DR     NaN
# 50                ACPM Podiatry Group LTD         5017 N Glen Park PL     NaN
#
#     OVAP Score
# 0         0.00
# 2        29.46
# 5        29.46
# 8        21.02
# 11       39.11
# 13       33.00
# 15       31.53
# 18       30.31
# 22       30.55
# 25       27.13
# 28       27.26
# 30        0.00
# 33       37.03
# 35       28.23
# 37       47.07
# 39       31.17
# 41        0.00
# 45        0.00
# 48       24.08
# 50       33.37

# %%
## 5. Prepare to join dataframes.

## 5.a Capitalize all addresses in inspections and OVAP_test dataframe to prepare for joining with buildings

## OVAP_test capitalization
OVAP_test['Address'] = OVAP_test['Address'].str.upper()
print(OVAP_test.head())

## inspections capitalization
inspections['Address1'] = inspections['Address1'].str.upper()
print(inspections.head())
# Out:
#                    Occupancy Name                 Address    Unit  OVAP Score
# 0      Academy of Okinawan Karate    8875 N KNOXVILLE AVE     NaN        0.00
# 2       the former Napoli's Pizza  2200 W WAR MEMORIAL DR  #DU19A       29.46
# 5         (Office w/ Unkown name)             701 MAIN ST      #7       29.46
# 8             (vacant mercantile)  2200 W WAR MEMORIAL DR   #DU08       21.02
# 11  1505 on the Avenue Apartments       1505 N PEORIA AVE     NaN       39.11
#                           Name                  Address1  Address2    City  \
# 0                  50's Dinner  4700 N UNIVERSITY ST #60       NaN  Peoria
# 1               8 Bit Beercade           100 STATE ST #A       NaN  Peoria
# 2             A WORLD OF WINGS            1024 W MAIN ST       NaN  PEORIA
# 3                   Agatucci's      2607 N UNIVERSITY ST       NaN  Peoria
# 4  Alexander Street Steakhouse         100 ALEXANDER AVE       NaN  Peoria
#
#   State    Zip         OccupancyType  BuildingHeight  NumberOfFloors  \
# 0    IL  61614       A-2 Restaurants             NaN             NaN
# 1    IL  61602  A-2 taverns and Bars             NaN             1.0
# 2    IL  61606       A-2 Restaurants             NaN             1.0
# 3    IL  61614       A-2 Restaurants             NaN             NaN
# 4    IL  61603       A-2 Restaurants             NaN             2.0
#
#    SquareFeet CriticalInfrastructure  YearBuilt NFIRSPropertyUse  \
# 0         NaN                    NaN        NaN              161
# 1      1900.0                    NaN        NaN              113
# 2      2000.0                    NaN        NaN              161
# 3         NaN                    NaN        NaN              161
# 4     20000.0                    NaN        NaN              161
#
#                      ConstructionTypeId
# 0  Ordinary (Joisted Masonry) Class III
# 1  Ordinary (Joisted Masonry) Class III
# 2  Ordinary (Joisted Masonry) Class III
# 3  Ordinary (Joisted Masonry) Class III
# 4                 Heavy Timber Class IV

# %%
## 6. Prepare to join dataframes.

## 6.a Rename buildings' and inspections' address columns to 'Address'

buildings.rename(columns={'full_address':'Address'}, inplace=True)
inspections.rename(columns={'Address1':'Address'}, inplace=True)

# %%
## 7. Join OVAP_test and buildings dataframes by the Address column

## 7.2 Join buildings and OVAP_test dataframes on shared 'Address' column

buildings_with_OVAP = pd.merge(buildings, OVAP_test)
buildings_with_OVAP.head()

## 7.3 Join buildings_with_OVAP and inspections on shared 'Address' column
joined_data = pd.merge(buildings_with_OVAP, inspections)

## AS FAR AS WE GOT
## !!Resulting joined_data need to be cleaned!!
print(joined_data.shape)
joined_data
# Out:
# (3735, 33)
#       feature_ID   lower_PIN         PIN  \
# 0              4   929378003   929378003
# 1              5   929378003   929378003
# 2             11   929104018   929104018
# 3719  PEORIA                  ...                     IL  61615
# 3720  PEORIA                  ...                     IL  61615
# 3721  PEORIA                  ...                     IL  61615
# 3722  PEORIA                  ...                     IL  61615
# 3723  PEORIA                  ...                     IL  61615
# 3724  PEORIA                  ...                     IL  61615
# 3725  PEORIA                  ...                     IL  61615
# 3726  PEORIA                  ...                     IL  61615
# 3727  PEORIA                  ...                     IL  61615
# 3728  PEORIA                  ...                     IL  61614
# 3729  PEORIA                  ...                     IL  61603
# 3730  PEORIA                  ...                     IL  61603
# 3731  PEORIA                  ...                     IL  61525
# 3732  PEORIA                  ...                     IL  61603
# 3733  PEORIA                  ...                     IL  61603
# 3734  PEORIA                  ...                     IL  61525
#
#                          OccupancyType BuildingHeight NumberOfFloors  \
# 0                          B- Business           30.0            1.0
# 1                          B- Business           30.0            1.0
# 2     M-Motor Vehicle Service Stations           25.0            1.0
# 3                          B- Business            NaN            1.0
# 4                          B- Business            NaN            NaN
# 5                          B- Business            NaN            NaN
# 6                          B- Business            NaN            2.0
# 7                          B- Business            NaN            NaN
# 8                          B- Business            NaN            1.0
# 9                          B- Business            NaN            NaN
# 10                         B- Business            NaN            NaN
# 11                         B- Business            NaN            2.0
# 12                         B- Business            NaN            NaN
# 13                         B- Business            NaN            1.0
# 14                         B- Business            NaN            NaN
# 15                         B- Business            NaN            NaN
# 16                         B- Business            NaN            2.0
# 17                         B- Business            NaN            NaN
# 18                         B- Business            NaN            1.0
# 19                         B- Business            NaN            NaN
# 20                         B- Business            NaN            NaN
# 21                         B- Business            NaN            2.0
# 22                         B- Business            NaN            NaN
# 23                         B- Business            NaN            1.0
# 24                         B- Business            NaN            NaN
# 25                         B- Business            NaN            NaN
# 26                         B- Business            NaN            2.0
# 27                         B- Business            NaN            NaN
# 28                         B- Business            NaN            1.0
# 29                         B- Business            NaN            NaN
# ...                                ...            ...            ...
# 3705                       B- Business           12.0            1.0
# 3706                       B- Business           12.0            1.0
# 3707                       B- Business           16.0            NaN
# 3708                       B- Business           12.0            1.0
# 3709                       B- Business           12.0            1.0
# 3710                       B- Business           12.0            1.0
# 3711                       B- Business           12.0            1.0
# 3712                       B- Business           12.0            1.0
# 3713                       B- Business           16.0            NaN
# 3714                       B- Business           12.0            1.0
# 3715                       B- Business           12.0            1.0
# 3716                       B- Business           12.0            1.0
# 3717                       B- Business           12.0            1.0
# 3718                       B- Business           12.0            1.0
# 3719                       B- Business           16.0            NaN
# 3720                       B- Business           12.0            1.0
# 3721                       B- Business           12.0            1.0
# 3722                       B- Business           12.0            1.0
# 3723                       B- Business           12.0            1.0
# 3724                       B- Business           12.0            1.0
# 3725                       B- Business           16.0            NaN
# 3726                         R-1 Hotel            NaN            3.0
# 3727                    M- Drug Stores           25.0            1.0
# 3728                               R-3            NaN            0.0
# 3729                   A-2 Restaurants           30.0            1.0
# 3730                   A-2 Restaurants            NaN            1.0
# 3731     M- Retail or Wholesale Stores            NaN            NaN
# 3732                   A-2 Restaurants           30.0            1.0
# 3733                   A-2 Restaurants            NaN            1.0
# 3734     M- Retail or Wholesale Stores            NaN            NaN
#
#      SquareFeet CriticalInfrastructure YearBuilt NFIRSPropertyUse  \
# 0        4500.0                    NaN       NaN              571
# 1        4500.0                    NaN       NaN              571
# 2       15000.0                    NaN       NaN              571
# 3           0.0                    NaN       NaN              500
# 4           NaN                    NaN       NaN              NaN
# 5           NaN                    NaN       NaN              581
# 6       48000.0                    NaN       NaN              519
# 7           NaN                    NaN       NaN              NaN
# 8           0.0                    NaN       NaN              500
# 9           NaN                    NaN       NaN              NaN
# 10          NaN                    NaN       NaN              581
# 11      48000.0                    NaN       NaN              519
# 12          NaN                    NaN       NaN              NaN
# 13          0.0                    NaN       NaN              500
# 14          NaN                    NaN       NaN              NaN
# 15          NaN                    NaN       NaN              581
# 16      48000.0                    NaN       NaN              519
# 17          NaN                    NaN       NaN              NaN
# 18          0.0                    NaN       NaN              500
# 19          NaN                    NaN       NaN              NaN
# 20          NaN                    NaN       NaN              581
# 21      48000.0                    NaN       NaN              519
# 22          NaN                    NaN       NaN              NaN
# 23          0.0                    NaN       NaN              500
# 24          NaN                    NaN       NaN              NaN
# 25          NaN                    NaN       NaN              581
# 26      48000.0                    NaN       NaN              519
# 27          NaN                    NaN       NaN              NaN
# 28          0.0                    NaN       NaN              500
# 29          NaN                    NaN       NaN              NaN
# ...         ...                    ...       ...              ...
# 3705      750.0                    NaN       NaN              500
# 3706      750.0                    NaN       NaN              500
# 3707    10880.0                    NaN       NaN              500
# 3708      750.0                    NaN       NaN              500
# 3709      750.0          Public Health       NaN              500
# 3710      750.0                    NaN       NaN              500
# 3711      750.0                    NaN       NaN              500
# 3712      750.0                    NaN       NaN              500
# 3713    10880.0                    NaN       NaN              500
# 3714      750.0                    NaN       NaN              500
# 3715      750.0          Public Health       NaN              500
# 3716      750.0                    NaN       NaN              500
# 3717      750.0                    NaN       NaN              500
# 3718      750.0                    NaN       NaN              500
# 3719    10880.0                    NaN       NaN              500
# 3720      750.0                    NaN       NaN              500
# 3721      750.0          Public Health       NaN              500
# 3722      750.0                    NaN       NaN              500
# 3723      750.0                    NaN       NaN              500
# 3724      750.0                    NaN       NaN              500
# 3725    10880.0                    NaN       NaN              500
# 3726    71400.0                    NaN    2000.0              449
# 3727     8000.0                    NaN       NaN              519
# 3728        0.0                    NaN       NaN              459
# 3729     2532.0                    NaN       NaN              160
# 3730     1519.0                    NaN       NaN              161
# 3731        NaN                    NaN       NaN              580
# 3732     2532.0                    NaN       NaN              160
# 3733     1519.0                    NaN       NaN              161
# 3734        NaN                    NaN       NaN              580
#
#                         ConstructionTypeId
# 0     Ordinary (Joisted Masonry) Class III
# 1     Ordinary (Joisted Masonry) Class III
# 2     Ordinary (Joisted Masonry) Class III
# 3     Ordinary (Joisted Masonry) Class III
# 4     Ordinary (Joisted Masonry) Class III
# 5     Ordinary (Joisted Masonry) Class III
# 6     Ordinary (Joisted Masonry) Class III
# 30                   KROGER LIMITED PARTNERSHIP I
# 31                   KROGER LIMITED PARTNERSHIP I
# 32                   KROGER LIMITED PARTNERSHIP I
# ...                                           ...
# 3026                             NBIM SHERIDAN LP
# 3027                             NBIM SHERIDAN LP
# 3028                             NBIM SHERIDAN LP
# 3029                             NBIM SHERIDAN LP
# 3030                             NBIM SHERIDAN LP
# 3031                             NBIM SHERIDAN LP
# 3032                             NBIM SHERIDAN LP
# 3033                             NBIM SHERIDAN LP
# 3034                             NBIM SHERIDAN LP
# 3035                             NBIM SHERIDAN LP
# 3036                             NBIM SHERIDAN LP
# 3037                             NBIM SHERIDAN LP
# 3038                             NBIM SHERIDAN LP
# 3039                             NBIM SHERIDAN LP
# 3040                             NBIM SHERIDAN LP
# 3041                             NBIM SHERIDAN LP
# 3042                             NBIM SHERIDAN LP
# 3127  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3128  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3129  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3130  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3131  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3132  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3133  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3134  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3135  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3136  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3137  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3138  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
# 3139  PLEASURE DRIVEWAY & PARK DISTRICT OF PEORIA
#
#                               owner_address                 owner_address2  \
# 3                    PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 4                    PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 5                    PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 6                    PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 7                    PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 8                    PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 9                    PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 10                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 11                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 12                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 13                        ONE RIVERSHIRE LN
# 14                        ONE RIVERSHIRE LN
# 15                        ONE RIVERSHIRE LN
# 16                        ONE RIVERSHIRE LN
# 17                        ONE RIVERSHIRE LN
# 18                        ONE RIVERSHIRE LN
# 19                        ONE RIVERSHIRE LN
# 20                        ONE RIVERSHIRE LN
# 21                        ONE RIVERSHIRE LN
# 22                        ONE RIVERSHIRE LN
# 23                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 24                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 25                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 26                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 27                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 28                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 29                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 30                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 31                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# 32                   PROPERTY TAX 7TH FLOOR                   1014 VINE ST
# ...                                     ...                            ...
# 3026  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3027  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3028  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3029  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3030  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3031  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3032  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3033  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3034  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3035  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3036  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3037  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3038  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3039  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3040  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3041  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3042  C/O NORTHBRIDGE INVESTMENT MANAGEMENT  80 RICHMOND ST WEST SUITE 600
# 3127            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3128            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3129            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3130            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3131            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3132            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3133            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3134            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3135            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3136            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3137            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3138            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
# 3139            NOBLE ADMINISTRATION CENTER                1125 W LAKE AVE
#
#         owner_city owner_state             Address    city  \
# 3       CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 4       CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 5       CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 6       CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 7       CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 8       CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 9       CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 10      CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 11      CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 12      CINCINNATI          OH      801 W LAKE AVE  PEORIA
# 13    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 14    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 15    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 16    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 17    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 18    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 19    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 20    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 21    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 22    LINCOLNSHIRE          IL      801 W LAKE AVE  PEORIA
# 23      CINCINNATI          OH      801 W LAKE AVE  PEORIA
#
# ...                   ...                    ...    ...
# 3026                  ...                     IL  61614
# 3027                  ...                     IL  61614
# 3028                  ...                     IL  61614
# 3029                  ...                     IL  61614
# 3030                  ...                     IL  61614
# 3031                  ...                     IL  61614
# 3032                  ...                     IL  61614
# 3033                  ...                     IL  61614
# 3034                  ...                     IL  61614
# 3035                  ...                     IL  61614
# 3036                  ...                     IL  61614
# 3037                  ...                     IL  61614
# 3038                  ...                     IL  61614
# 3039                  ...                     IL  61614
# 3040                  ...                     IL  61614
# 3041                  ...                     IL  61614
# 3042                  ...                     IL  61614
# 3127                  ...                     IL  61614
# 3128                  ...                     IL  61614
# 3129                  ...                     IL  61614
# 3130                  ...                     IL  61614
# 3131                  ...                     IL  61614
# 3132                  ...                     IL  61614
# 3133                  ...                     IL  61614
# 3134                  ...                     IL  61614
# 3135                  ...                     IL  61614
# 3136                  ...                     IL  61614
# 3137                  ...                     IL  61614
# 3138                  ...                     IL  61614
# 3139                  ...                     IL  61614
#
#                       OccupancyType BuildingHeight NumberOfFloors SquareFeet  \
# 3                       B- Business            NaN            1.0        0.0
# 4                       B- Business            NaN            NaN        NaN
# 5                       B- Business            NaN            NaN        NaN
# 6                       B- Business            NaN            2.0    48000.0
# 7                       B- Business            NaN            NaN        NaN
# 8                       B- Business            NaN            1.0        0.0
# 9                       B- Business            NaN            NaN        NaN
# 10                      B- Business            NaN            NaN        NaN
# 11                      B- Business            NaN            2.0    48000.0
# 12                      B- Business            NaN            NaN        NaN
# 13                      B- Business            NaN            1.0        0.0
# 14                      B- Business            NaN            NaN        NaN
# 15                      B- Business            NaN            NaN        NaN
# 16                      B- Business            NaN            2.0    48000.0
# 17                      B- Business            NaN            NaN        NaN
# 18                      B- Business            NaN            1.0        0.0
# 19                      B- Business            NaN            NaN        NaN
# 20                      B- Business            NaN            NaN        NaN
# 21                      B- Business            NaN            2.0    48000.0
# 22                      B- Business            NaN            NaN        NaN
# 23                      B- Business            NaN            1.0        0.0
# 24                      B- Business            NaN            NaN        NaN
# 25                      B- Business            NaN            NaN        NaN
# 26                      B- Business            NaN            2.0    48000.0
# 27                      B- Business            NaN            NaN        NaN
# 28                      B- Business            NaN            1.0        0.0
# 29                      B- Business            NaN            NaN        NaN
# 30                      B- Business            NaN            NaN        NaN
# 31                      B- Business            NaN            2.0    48000.0
# 32                      B- Business            NaN            NaN        NaN
# ...                             ...            ...            ...        ...
# 3026  M- Retail or Wholesale Stores           15.0            1.0     1800.0
# 3027  M- Retail or Wholesale Stores           10.0            1.0     1800.0
# 3028  M- Retail or Wholesale Stores            NaN            NaN        NaN
# 3029  M- Retail or Wholesale Stores           10.0            1.0     1800.0
# 3030  M- Retail or Wholesale Stores           15.0            1.0     1500.0
# 3031           M- Department Stores            NaN            NaN        NaN
# 3032  M- Retail or Wholesale Stores           15.0            1.0     1800.0
# 3033  M- Retail or Wholesale Stores           10.0            1.0     1800.0
# 3034  M- Retail or Wholesale Stores            NaN            NaN        NaN
# 3035  M- Retail or Wholesale Stores           10.0            1.0     1800.0
# 3036  M- Retail or Wholesale Stores           15.0            1.0     1500.0
# 3037           M- Department Stores            NaN            NaN        NaN
# 3038  M- Retail or Wholesale Stores           15.0            1.0     1800.0
# 3039  M- Retail or Wholesale Stores           10.0            1.0     1800.0
# 3040  M- Retail or Wholesale Stores            NaN            NaN        NaN
# 3041  M- Retail or Wholesale Stores           10.0            1.0     1800.0
# 3042  M- Retail or Wholesale Stores           15.0            1.0     1500.0
# 3127             A-4 Swimming Pools            NaN            1.0     3000.0
# 3128                    B- Business            NaN            NaN        NaN
# 3129             A-4 Swimming Pools            NaN            1.0     3000.0
# 3130                    B- Business            NaN            NaN        NaN
# 3131             A-4 Swimming Pools            NaN            1.0     3000.0
# 3132                    B- Business            NaN            NaN        NaN
# 3133             A-4 Swimming Pools            NaN            1.0     3000.0
# 3134                    B- Business            NaN            NaN        NaN
# 3135             A-4 Swimming Pools            NaN            1.0     3000.0
# 3136                    B- Business            NaN            NaN        NaN
# 3137             A-4 Swimming Pools            NaN            1.0     3000.0
# 3138                    B- Business            NaN            NaN        NaN
# 3139                    B- Business           20.0            2.0    40000.0
#
#      CriticalInfrastructure YearBuilt NFIRSPropertyUse  \
# 3                       NaN       NaN              500
# 4                       NaN       NaN              NaN
# 5                       NaN       NaN              581
# 6                       NaN       NaN              519
# 7                       NaN       NaN              NaN
# 8                       NaN       NaN              500
# 9                       NaN       NaN              NaN
# 10                      NaN       NaN              581
# 11                      NaN       NaN              519
# 12                      NaN       NaN              NaN
# 13                      NaN       NaN              500
# 14                      NaN       NaN              NaN
# 15                      NaN       NaN              581
# 16                      NaN       NaN              519
# 17                      NaN       NaN              NaN
# 18                      NaN       NaN              500
# 19                      NaN       NaN              NaN
# 20                      NaN       NaN              581
# 21                      NaN       NaN              519
# 22                      NaN       NaN              NaN
# 23                      NaN       NaN              500
# 24                      NaN       NaN              NaN
# 25                      NaN       NaN              581
# 26                      NaN       NaN              519
# 27                      NaN       NaN              NaN
# 28                      NaN       NaN              500
# 29                      NaN       NaN              NaN
# 30                      NaN       NaN              581
# 31                      NaN       NaN              519
# 32                      NaN       NaN              NaN
# ...                     ...       ...              ...
# 3026                    NaN       NaN              581
# 3027                    NaN       NaN              581
# 3028                    NaN       NaN              581
# 3029                    NaN       NaN              581
# 3030                    NaN       NaN              581
# 3031                    NaN       NaN              581
# 3032                    NaN       NaN              581
# 3033                    NaN       NaN              581
# 3034                    NaN       NaN              581
# 3035                    NaN       NaN              581
# 3036                    NaN       NaN              581
# 3037                    NaN       NaN              581
# 3038                    NaN       NaN              581
# 3039                    NaN       NaN              581
# 3040                    NaN       NaN              581
# 3041                    NaN       NaN              581
# 3042                    NaN       NaN              581
# 3127                    NaN       NaN              116
# 3128                    NaN       NaN              599
# 3129                    NaN       NaN              116
# 3130                    NaN       NaN              599
# 3131                    NaN       NaN              116
# 3132                    NaN       NaN              599
# 3133                    NaN       NaN              116
# 3134                    NaN       NaN              599
# 3135                    NaN       NaN              116
# 3136                    NaN       NaN              599
# 3137                    NaN       NaN              116
# 3138                    NaN       NaN              599
# 3139                    NaN    1960.0              599
#
#                         ConstructionTypeId
# 3     Ordinary (Joisted Masonry) Class III
# 4     Ordinary (Joisted Masonry) Class III
# 5     Ordinary (Joisted Masonry) Class III
# 6     Ordinary (Joisted Masonry) Class III
# 7     Ordinary (Joisted Masonry) Class III
# 8     Ordinary (Joisted Masonry) Class III
# 9     Ordinary (Joisted Masonry) Class III
# 10    Ordinary (Joisted Masonry) Class III
# 11    Ordinary (Joisted Masonry) Class III
# 12    Ordinary (Joisted Masonry) Class III
# 13    Ordinary (Joisted Masonry) Class III
# 14    Ordinary (Joisted Masonry) Class III
# 15    Ordinary (Joisted Masonry) Class III
# 16    Ordinary (Joisted Masonry) Class III
# 17    Ordinary (Joisted Masonry) Class III
# 18    Ordinary (Joisted Masonry) Class III
# 19    Ordinary (Joisted Masonry) Class III
# 20    Ordinary (Joisted Masonry) Class III
# 21    Ordinary (Joisted Masonry) Class III
# 22    Ordinary (Joisted Masonry) Class III
# 23    Ordinary (Joisted Masonry) Class III
# 24    Ordinary (Joisted Masonry) Class III
# 25    Ordinary (Joisted Masonry) Class III
# 26    Ordinary (Joisted Masonry) Class III
# 27    Ordinary (Joisted Masonry) Class III
# 28    Ordinary (Joisted Masonry) Class III
# 29    Ordinary (Joisted Masonry) Class III
# 30    Ordinary (Joisted Masonry) Class III
# 31    Ordinary (Joisted Masonry) Class III
# 32    Ordinary (Joisted Masonry) Class III
# ...                                    ...
# 3026  Non-Combustible (All Metal) Class II
# 3027  Ordinary (Joisted Masonry) Class III
# 3028  Non-Combustible (All Metal) Class II
# 3029  Non-Combustible (All Metal) Class II
# 3030  Non-Combustible (All Metal) Class II
# 3031                    Wood Frame Class V
# 3032  Non-Combustible (All Metal) Class II
# 3033  Ordinary (Joisted Masonry) Class III
# 3034  Non-Combustible (All Metal) Class II
# 3035  Non-Combustible (All Metal) Class II
# 3036  Non-Combustible (All Metal) Class II
# 3037                    Wood Frame Class V
# 3038  Non-Combustible (All Metal) Class II
# 3039  Ordinary (Joisted Masonry) Class III
# 3040  Non-Combustible (All Metal) Class II
# 3041  Non-Combustible (All Metal) Class II
# 3042  Non-Combustible (All Metal) Class II
# 3127     Non-Combustible (Masonry) Class I
# 3128  Non-Combustible (All Metal) Class II
# 3129     Non-Combustible (Masonry) Class I
# 3130  Non-Combustible (All Metal) Class II
# 3131     Non-Combustible (Masonry) Class I
# 3132  Non-Combustible (All Metal) Class II
# 3133     Non-Combustible (Masonry) Class I
# 3134  Non-Combustible (All Metal) Class II
# 3135     Non-Combustible (Masonry) Class I
# 3136  Non-Combustible (All Metal) Class II
# 3137     Non-Combustible (Masonry) Class I
# 3138  Non-Combustible (All Metal) Class II
# 3139     Non-Combustible (Masonry) Class I
#
# [209 rows x 33 columns]
